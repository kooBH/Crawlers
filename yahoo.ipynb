# %%
import fix_yahoo_finance as yf
import datetime as dt 
start = dt.datetime(1990, 1, 1)
end = dt.datetime.utcnow()
yf.download('005930.KS', start = start, end = end)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#             Adj Close    Close     High      Low     Open     Volume
# Date
# 2000-01-04       0.09   6110.0   6110.0   5660.0   6000.0   74195000
# 2000-01-05       0.08   5580.0   6060.0   5520.0   5800.0   74680000
# 2000-01-06       0.08   5620.0   5780.0   5580.0   5750.0   54390000
# 2000-01-07       0.08   5540.0   5670.0   5360.0   5560.0   40305000
# 2000-01-10       0.09   5770.0   5770.0   5580.0   5600.0   46880000
# 2000-01-11       0.09   5770.0   6100.0   5770.0   5820.0   59745000
# 2000-01-12       0.08   5720.0   5740.0   5600.0   5610.0   29220000
# 2000-01-13       0.08   5710.0   5740.0   5560.0   5600.0   41190000
# 2000-01-14       0.09   5830.0   5880.0   5680.0   5720.0   49375000
# 2000-01-17       0.09   6100.0   6180.0   5920.0   6000.0   63505000
# 2000-01-18       0.09   6100.0   6160.0   5980.0   6160.0   45260000
# ...
